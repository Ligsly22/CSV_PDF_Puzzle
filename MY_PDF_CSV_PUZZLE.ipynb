# %%
import csv
import re

# %%
with open('find_the_link.csv', newline='') as f:
    data = list(csv.reader(f))

link = ''
for i in range(len(data)):
    link += data[i][i]

print(link)
# Out:
# https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print("CWD:", os.getcwd())
print("Files here:", [f for f in os.listdir() if f.lower().endswith(".pdf")])
# Out:
# CWD: /Users/ligs22/Complete-Python-3-Bootcamp-master/15-PDFs-and-Spreadsheets/Exercise_Files
# Files here: ['Find_the_Phone_Number.pdf']

# %%
from PyPDF2 import PdfReader

with open('Find_the_Phone_Number.pdf', 'rb') as f:
    reader = PdfReader(f)
    for page in reader.pages:
        text = page.extract_text() or ''
        pattern = r'\d{3}\D+\d{3}\D+\d{4}'

        match = re.search(pattern, text)
        if match:
            print(match.group())
# Out:
# 505.503.4455
